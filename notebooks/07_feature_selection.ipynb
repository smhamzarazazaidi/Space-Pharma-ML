# %% [markdown]
# # 07. Feature Selection
#
# **Project:** Interpretable Small-Data ML for Predicting Pharmaceutical Response and Stability Under Long-Duration Spaceflight Conditions
# **Single Source of Truth:** `docs/RESEARCH_DOCUMENT.md` (Sections 11.8, 15)
#
# ## Objectives:
# 1. Perform feature ranking and selection (L1 penalty, recursive feature elimination, permutation importance).
# 2. Avoid overfitting in low sample regimes by retaining a parsimonious feature set.
# 3. Record selected feature sets and stability scores in `docs/RESEARCH_DOCUMENT.md`.

# %%
from sklearn.feature_selection import RFE, SelectFromModel
from sklearn.inspection import permutation_importance

print("Feature selection module ready.")
