# %% [markdown]
# # 10. Rigorous Validation & Sensitivity Analysis
#
# **Project:** Interpretable Small-Data ML for Predicting Pharmaceutical Response and Stability Under Long-Duration Spaceflight Conditions
# **Single Source of Truth:** `docs/RESEARCH_DOCUMENT.md` (Sections 11.11, 11.12, 12, 15)
#
# ## Objectives:
# 1. Perform grouped validation (Leave-One-Study-Out, Leave-One-Drug-Out) to prevent data leakage.
# 2. Estimate 95% bootstrap confidence intervals across performance metrics.
# 3. Perform sensitivity analysis under input perturbations and simulate deep-space stressor bounds.
# 4. Document all validation outcomes and limitations in `docs/RESEARCH_DOCUMENT.md`.

# %%
from sklearn.model_selection import LeaveOneGroupOut, GroupKFold
import numpy as np

print("Validation and sensitivity analysis framework initialized.")
