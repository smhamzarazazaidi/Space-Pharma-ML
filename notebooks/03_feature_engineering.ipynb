# %% [markdown]
# # 03. Feature Engineering
#
# **Project:** Interpretable Small-Data ML for Predicting Pharmaceutical Response and Stability Under Long-Duration Spaceflight Conditions
# **Single Source of Truth:** `docs/RESEARCH_DOCUMENT.md` (Sections 10, 11.5)
#
# ## Objectives:
# 1. Engineer domain-relevant features combining flight duration, radiation dose, chemical/physicochemical properties, and biological indicators.
# 2. Prepare final tabular matrices in `data/processed/`.
# 3. Log engineered features and mathematical rationale in `docs/RESEARCH_DOCUMENT.md`.

# %%
from pathlib import Path
import pandas as pd

INTERIM_DIR = Path("../data/interim")
PROCESSED_DIR = Path("../data/processed")
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

print("Feature engineering module initialized.")
