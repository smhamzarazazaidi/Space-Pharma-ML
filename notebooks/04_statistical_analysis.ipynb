# %% [markdown]
# # 04. Statistical Analysis & Hypothesis Testing
#
# **Project:** Interpretable Small-Data ML for Predicting Pharmaceutical Response and Stability Under Long-Duration Spaceflight Conditions
# **Single Source of Truth:** `docs/RESEARCH_DOCUMENT.md` (Sections 11.4, 15)
#
# ## Objectives:
# 1. Perform non-parametric tests (Mann-Whitney U, Wilcoxon, Kruskal-Wallis) suitable for small samples.
# 2. Evaluate correlation matrices (Spearman rank, Kendall's tau) between spaceflight factors and target outcomes.
# 3. Log all statistical outcomes and effect sizes in `docs/RESEARCH_DOCUMENT.md`.

# %%
from pathlib import Path
import scipy.stats as stats
import pandas as pd

print("Statistical analysis workspace initialized.")
