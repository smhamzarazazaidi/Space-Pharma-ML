# %% [markdown]
# # 05. Baseline Models
#
# **Project:** Interpretable Small-Data ML for Predicting Pharmaceutical Response and Stability Under Long-Duration Spaceflight Conditions
# **Single Source of Truth:** `docs/RESEARCH_DOCUMENT.md` (Sections 11.6, 15)
#
# ## Objectives:
# 1. Implement non-learning baselines (Mean/Median regressor) and linear baselines (OLS, Ridge, Lasso).
# 2. Establish benchmark performance (MAE, RMSE, R²) using appropriate grouped cross-validation.
# 3. Record benchmark metrics in `docs/RESEARCH_DOCUMENT.md`.

# %%
from pathlib import Path
import yaml
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso

print("Baseline model evaluation workspace initialized.")
