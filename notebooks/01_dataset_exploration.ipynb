# %% [markdown]
# # 01. Dataset Exploration & Initial Audit
#
# **Project:** Interpretable Small-Data ML for Predicting Pharmaceutical Response and Stability Under Long-Duration Spaceflight Conditions
# **Single Source of Truth:** `docs/RESEARCH_DOCUMENT.md` (Sections 7, 8, 9)
#
# ## Objectives:
# 1. Inspect raw candidate files downloaded from verified repositories (e.g. NASA OSDR, pharmaceutical stability studies).
# 2. Check sample dimensions, column names, missingness, and data types without altering raw files.
# 3. Record all observations directly into `docs/RESEARCH_DOCUMENT.md`.
#
# > **Research Integrity Rule:** Do not fabricate or simulate data. Datasets will only be loaded when actual verified files are placed in `data/raw/`.

# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path

# Paths
RAW_DIR = Path("../data/raw")
print(f"Raw data directory: {RAW_DIR.resolve()}")
print(f"Available subdirectories: {[d.name for d in RAW_DIR.iterdir() if d.is_dir()]}")
