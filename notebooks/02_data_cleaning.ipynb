# %% [markdown]
# # 02. Data Cleaning & Standardization
#
# **Project:** Interpretable Small-Data ML for Predicting Pharmaceutical Response and Stability Under Long-Duration Spaceflight Conditions
# **Single Source of Truth:** `docs/RESEARCH_DOCUMENT.md` (Sections 10, 11.2)
#
# ## Objectives:
# 1. Handle missing values, unit standardizations, and cross-study nomenclature alignment.
# 2. Never overwrite raw data; save cleaned datasets to `data/interim/`.
# 3. Maintain a complete audit log of cleaning decisions in `docs/RESEARCH_DOCUMENT.md`.

# %%
from pathlib import Path
import pandas as pd

RAW_DIR = Path("../data/raw")
INTERIM_DIR = Path("../data/interim")
INTERIM_DIR.mkdir(parents=True, exist_ok=True)

print("Ready for data cleaning pipeline once raw files are audited.")
